# %% [markdown]
# <a href="https://colab.research.google.com/github/asmaElouali/ArabicOCR/blob/main/ArabicOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ArabicOcr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 38.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 30.6 MB/s eta 0:00:00
# ...

# %%
from ArabicOcr import arabicocr
image_path='8.jpg'
out_image='out.jpg'
results=arabicocr.arabic_ocr(image_path,out_image)
print(results)
words=[]
for i in range(len(results)):
		word=results[i][1]
		words.append(word)
with open ('file.txt','w',encoding='utf-8')as myfile:
		myfile.write(str(words))
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9948: DU MAROC
# [INFO] 0.8881: البطاقة الوطنية [
# [INFO] 0.7994: CARTE NATIONALE D'IDENTITE
# [INFO] 0.6455: البخا
# [INFO] 0.8897: ILIASS
# [INFO] 0.8482: دى
# [INFO] 0.9994: مزداد
# [INFO] 0.9664: ٤L
# [INFO] 0.7739: 16.07.1992
# [INFO] 0.6801: جنان
# [INFO] 0.8057: Ne le
# [INFO] 0.8563: FES
# [INFO] 0.9064: صالحة الى غاية
# [INFO] 0.9925: MH
# [INFO] 0.8590: ٤L
# [INFO] 0.5936: 0
# [INFO] 0.9596: 027
# [INFO] 0.9809: 21
# [INFO] 0.9998: Valable
# [INFO] 0.1773: المملك2 المغربية
# [INFO] 0.9441:  للتعريف
# [INFO] 0.8011: ROYAUME
# [INFO] 0.5690: الياس
# [INFO] 0.9948: BOUKHARI
# [INFO] 0.5200: نارىخ
# [INFO] 0.7452: الورد
# [INFO] 0.9937: OUARD
# [INFO] 0.8721: JNANE
# [INFO] 0.7940: C0198394
# [INFO] 0.7642: المدير
# [INFO] 0.4484: | jusqu'a٧
# [INFO] 0.6248: الوطن
# [INFO] 0.1843: اللطم
# [INFO] 0.2469: عبد
# [INFO] 0.7542: حموشي
# ...

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# For example, here we download and display a PNG image of the Colab logo:

# %%
import cv2
img = cv2.imread('out.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x606>
